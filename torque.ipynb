# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

# داده‌های time، Result-H و Result-M
time = list(range(41))
result_h = [
   31.89, 32.454, 32.97, 33.438, 33.856, 34.228, 34.55, 34.826, 35.056, 35.236, 35.37,
   35.458, 35.498, 35.494, 35.442, 35.348, 35.208, 35.024, 34.796, 34.544, 34.212,
   34.572, 34.796, 35.024, 35.208, 35.348, 35.442, 35.494, 35.498, 35.458, 35.37,
    35.236, 35.056, 34.826, 34.55, 34.228, 33.856, 33.438, 32.97, 32.454, 31.89
  
]

result_m = [
     2.154, 2.536, 2.91, 3.23, 3.544, 3.836, 4.104, 4.312, 4.578, 4.782, 4.962, 5.122, 5.264, 5.378, 5.476, 5.552, 5.614, 5.642, 5.654, 5.65, 5.626, 
     5.65, 5.654, 5.642, 5.614, 5.552, 5.476, 5.378, 5.264, 5.122, 4.962, 4.782, 4.578, 4.312, 4.104, 3.836, 3.544, 3.23, 2.91, 2.536, 2.154

]

# رسم نمودار
plt.figure(figsize=(10, 6))
plt.plot(time, result_h, marker='o', linestyle='-', color='r', label='Hadi')
plt.plot(time, result_m, marker='o', linestyle='-', color='b', label='Michael')

# افزودن عنوان و برچسب‌ها
plt.title('Hadi & Michael')
plt.xlabel('time')
plt.ylabel('torque')

# افزودن راهنما
plt.legend()

# نمایش نمودار
plt.grid(True)
plt.show()
plt.savefig("/home/iman/Desktop/torquegraph.png")

# %%
import matplotlib.pyplot as plt

# داده‌های time، Result-H و Result-M
time = list(range(41))
result_h = [
   31.89, 32.454, 32.97, 33.438, 33.856, 34.228, 34.55, 34.826, 35.056, 35.236, 35.37,
   35.458, 35.498, 35.494, 35.442, 35.348, 35.208, 35.024, 34.796, 34.544, 34.212,
   34.572, 34.796, 35.024, 35.208, 35.348, 35.442, 35.494, 35.498, 35.458, 35.37,
    35.236, 35.056, 34.826, 34.55, 34.228, 33.856, 33.438, 32.97, 32.454, 31.89 
]

# رسم نمودار
plt.figure(figsize=(10, 6))
plt.plot(time, result_h, marker='o', linestyle='-', color='r', label='Hadi')


# افزودن عنوان و برچسب‌ها
plt.title('Hadi')
plt.xlabel('time')
plt.ylabel('torque')

# افزودن راهنما
plt.legend()

# نمایش نمودار
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt


time = list(range(41))


result_m = [
     2.154, 2.536, 2.91, 3.23, 3.544, 3.836, 4.104, 4.312, 4.578, 4.782, 4.962, 5.122, 5.264, 5.378, 5.476, 5.552, 5.614, 5.642, 5.654, 5.65, 5.626, 
     5.65, 5.654, 5.642, 5.614, 5.552, 5.476, 5.378, 5.264, 5.122, 4.962, 4.782, 4.578, 4.312, 4.104, 3.836, 3.544, 3.23, 2.91, 2.536, 2.154

]

# رسم نمودار
plt.figure(figsize=(10, 6))

plt.plot(time, result_m, marker='o', linestyle='-', color='b', label='Michael')

# افزودن عنوان و برچسب‌ها
plt.title(' Michael')
plt.xlabel('time')
plt.ylabel('torque')

# افزودن راهنما
plt.legend()

# نمایش نمودار
plt.grid(True)
plt.show()
