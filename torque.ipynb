# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.0 MB 16.4 MB/s eta 0:00:01
#    --- ------------------------------------ 0.8/8.0 MB 1.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.0/8.0 MB 2.1 MB/s eta 0:00:04
#    --------- ------------------------------ 1.8/8.0 MB 2.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.4/8.0 MB 2.3 MB/s eta 0:00:03
#    ------------- -------------------------- 2.6/8.0 MB 2.2 MB/s eta 0:00:03
#    ------------- -------------------------- 2.6/8.0 MB 2.2 MB/s eta 0:00:03
#    ------------- -------------------------- 2.6/8.0 MB 2.2 MB/s eta 0:00:03
#    ------------- -------------------------- 2.6/8.0 MB 2.2 MB/s eta 0:00:03
#    ------------- -------------------------- 2.6/8.0 MB 2.2 MB/s eta 0:00:03
# ...

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

time = list(range(41))
result_h = [
   31.89,32.454,32.97,33.438,33.856,34.228,34.55,34.826,35.056,35.236,35.37,34.282,33.146,31.966,30.738,29.468,28.152,26.792,25.388,23.96,22.452,23.96,
    25.388,26.792,28.152,29.468,30.738,31.966,33.146,34.282,35.37,35.236,35.056,34.826,34.55,34.228,33.856,33.438,32.97,32.454,31.89
]

# رسم نمودار
plt.figure(figsize=(10, 6))
plt.plot(time, result_h, marker='o', linestyle='-', color='r', label='Hadi')


# افزودن عنوان و برچسب‌ها
plt.title('Hadi')
plt.xlabel('time')
plt.ylabel('torque')

# افزودن راهنما
plt.legend()

# نمایش نمودار
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

time = list(range(41))

result_m = [
     10.856,11.238,11.596,11.932,12.244,12.538,12.806,13.014,13.28,13.484,13.664,13.04,12.398,11.728,11.042,10.334,9.604,8.856,8.084,7.296,6.488,7.296,
    8.084,8.856,9.604,10.334,11.042,11.728,12.398,13.04,13.664,13.484,13.28,13.014,12.806,12.538,12.246,11.932,11.596,11.238,10.856
]

# رسم نمودار
plt.figure(figsize=(10, 6))

plt.plot(time, result_m, marker='o', linestyle='-', color='b', label='Michael')

# افزودن عنوان و برچسب‌ها
plt.title(' Michael')
plt.xlabel('time')
plt.ylabel('torque')

# افزودن راهنما
plt.legend()

# نمایش نمودار
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt


time = list(range(41))
result_h = [
   31.89,32.454,32.97,33.438,33.856,34.228,34.55,34.826,35.056,35.236,35.37,34.282,33.146,31.966,30.738,29.468,28.152,26.792,25.388,23.96,22.452,23.96,
    25.388,26.792,28.152,29.468,30.738,31.966,33.146,34.282,35.37,35.236,35.056,34.826,34.55,34.228,33.856,33.438,32.97,32.454,31.89 
]

result_m = [
       10.856,11.238,11.596,11.932,12.244,12.538,12.806,13.014,13.28,13.484,13.664,13.04,12.398,11.728,11.042,10.334,9.604,8.856,8.084,7.296,6.488,7.296,
    8.084,8.856,9.604,10.334,11.042,11.728,12.398,13.04,13.664,13.484,13.28,13.014,12.806,12.538,12.246,11.932,11.596,11.238,10.856
]

# رسم نمودار
plt.figure(figsize=(10, 6))
plt.plot(time, result_h, marker='o', linestyle='-', color='r', label='Hadi')
plt.plot(time, result_m, marker='o', linestyle='-', color='b', label='Michael')

# افزودن عنوان و برچسب‌ها
plt.title('Hadi & Michael')
plt.xlabel('time')
plt.ylabel('torque')

# افزودن راهنما
plt.legend()

# نمایش نمودار
plt.grid(True)
plt.show()
